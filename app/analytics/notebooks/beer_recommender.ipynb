# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 500)
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import seaborn as sns
import json

import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer, PorterStemmer 

from sklearn.metrics.pairwise import euclidean_distances, manhattan_distances, cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer
from itertools import islice
from scipy.spatial.distance import cdist
from scipy.stats.stats import pearsonr
import enchant
import os

# %%
import googletrans
from googletrans import Translator
import time
import re
import unicodedata

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
DATA_FOLDER = "data"
data_path = os.path.join(DATA_FOLDER) + "/"

if not DATA_FOLDER in os.listdir():
    os.mkdir(DATA_FOLDER)

# %% [markdown]
# # Read csv

# %%
df = pd.read_csv(data_path+'Beer_dataset_v2.csv', index_col=0)

# %%
df.head()
# Out:
#                                                  Name            Style  ABV  \
# 0  La Vella Caravana / Black Bitch Caravan of Bitches          Witbier  5.2
# 1                                  BlackLab Sour Lady  Berliner Weisse  5.0
# 2                            Blacklab Claudia Passion     American IPA  NaN
# 3                               BlackLab More Sparkle         Brut IPA  7.0
# 4                     Greyhound Brewers Give ’em Hops     Imperial IPA  8.0
#
#     IBU  Rating  \
# 0  29.0     NaN
# 1   NaN     NaN
# 2   NaN     NaN
# 3   NaN     NaN
# 4   NaN     NaN
#
#                                                                                                                                                                                              Description  \
# 0  Caravan of Bitches\nHoppy Wheat Ale\nEstilo tradicional elaborado con malta pilsner, trigo y avena. Este estilo se caracteriza por las adiciones de cascara de naranja amarga y semillas de cilantro.
# 1                                                                                  Sour Lady\nBerliner Weisse with fruit\nUna cerveza ácida con frambuesas.\n---------------\nSour beer with raspberries
# 2                                                                                        Claudia Passion\nFruit IPA\nNuestra mejor cerveza con Maracuyá\n--------------\nOur best IPA with passion fruit
# 3                                                                                            More Sparkle\nBrut IPA\nDry and aromatic. Low bitterness.\n-----------\nMuy seca y aromática. Poco amargor.
# 4                                                                                                                                                                             Give ’em Hops\nDoble NEIPA
#
#                               Brewery_full  \
# 0  La Vella CaravanaBlack Bitch Brewing Co
# 1                                 BlackLab
# 2                                 BlackLab
# 3                                 BlackLab
# 4                        Greyhound Brewers
#
#                                                                                                                                                                                         Description_full  \
# 0  Caravan of Bitches\nHoppy Wheat Ale\nEstilo tradicional elaborado con malta pilsner, trigo y avena. Este estilo se caracteriza por las adiciones de cascara de naranja amarga y semillas de cilantro.
# 1                                                                                  Sour Lady\nBerliner Weisse with fruit\nUna cerveza ácida con frambuesas.\n---------------\nSour beer with raspberries
# 2                                                                                        Claudia Passion\nFruit IPA\nNuestra mejor cerveza con Maracuyá\n--------------\nOur best IPA with passion fruit
# 3                                                                                            More Sparkle\nBrut IPA\nDry and aromatic. Low bitterness.\n-----------\nMuy seca y aromática. Poco amargor.
# 4                                                                                                                                                                             Give ’em Hops\nDoble NEIPA
#
#                                                                                                                                                Description_full_clean  \
# 0    estilo tradicional elaborado con malta pilsner, trigo y avena. este estilo se caracteriza por las adiciones de cascara de naranja amarga y semillas de cilantro.
# 1                                                                                                                                          sour beer with raspberries
# 2                                                                                                                                     our best ipa with passion fruit
# 3                                                                                                                                 muy seca y aromática. poco amargor.
# 4                                                                                                                                                         doble neipa
#
#                                          Name_clean
# 0  la vella caravana black bitch caravan of bitches
# 1                                blacklab sour lady
# 2                          blacklab claudia passion
# 3                             blacklab more sparkle
# 4                    greyhound brewers give em hops

# %%
columns = ['Name_clean', 'Brewery_full', 'Style', 'ABV', 'IBU', 'Description_full', 'Description_full_clean']
df = df[columns]

# %%
df.head()
# Out:
#                                          Name_clean  \
# 0  la vella caravana black bitch caravan of bitches
# 1                                blacklab sour lady
# 2                          blacklab claudia passion
# 3                             blacklab more sparkle
# 4                    greyhound brewers give em hops
#
#                               Brewery_full            Style  ABV   IBU  \
# 0  La Vella CaravanaBlack Bitch Brewing Co          Witbier  5.2  29.0
# 1                                 BlackLab  Berliner Weisse  5.0   NaN
# 2                                 BlackLab     American IPA  NaN   NaN
# 3                                 BlackLab         Brut IPA  7.0   NaN
# 4                        Greyhound Brewers     Imperial IPA  8.0   NaN
#
#                                                                                                                                                                                         Description_full  \
# 0  Caravan of Bitches\nHoppy Wheat Ale\nEstilo tradicional elaborado con malta pilsner, trigo y avena. Este estilo se caracteriza por las adiciones de cascara de naranja amarga y semillas de cilantro.
# 1                                                                                  Sour Lady\nBerliner Weisse with fruit\nUna cerveza ácida con frambuesas.\n---------------\nSour beer with raspberries
# 2                                                                                        Claudia Passion\nFruit IPA\nNuestra mejor cerveza con Maracuyá\n--------------\nOur best IPA with passion fruit
# 3                                                                                            More Sparkle\nBrut IPA\nDry and aromatic. Low bitterness.\n-----------\nMuy seca y aromática. Poco amargor.
# 4                                                                                                                                                                             Give ’em Hops\nDoble NEIPA
#
#                                                                                                                                                Description_full_clean
# 0    estilo tradicional elaborado con malta pilsner, trigo y avena. este estilo se caracteriza por las adiciones de cascara de naranja amarga y semillas de cilantro.
# 1                                                                                                                                          sour beer with raspberries
# 2                                                                                                                                     our best ipa with passion fruit
# 3                                                                                                                                 muy seca y aromática. poco amargor.
# 4                                                                                                                                                         doble neipa

# %%
df.isna().sum()
# Out:
# Name_clean                   0
# Brewery_full               385
# Style                        0
# ABV                        185
# IBU                       3298
# Description_full           413
# Description_full_clean     413
# dtype: int64

# %%
df.shape
# Out:
# (7879, 7)

# %%
df[df.Description_full.isna()]
# Out:
#                                            Name_clean        Brewery_full  \
# 29                              el pedal export stout                 NaN
# 33                 garage beer co scripted spiel wipa                 NaN
# 64                             a cova céltica fartura                 NaN
# 103                                   click brew iler                 NaN
# 105                          albert the great batch 1                 NaN
# 159                       beering barcelona fight ink                 NaN
# 207                           cervezahara la cachonda                 NaN
# 252                                 ruben s schwarz 2                 NaN
# 321                      kusfollin en el nom del porc                 NaN
# 333                    entre fronteras la chisparrera                 NaN
# 381                      cerveza bachiella milk stout                 NaN
# 382                   barcino brewers bogatell blonde                 NaN
# 383                  doskiwis brewing co heartbreaker                 NaN
# 386                          cyclic beer farm fresita                 NaN
# 471                       catalan brewery beach bunny                 NaN
# 523                        beer art project la rambla                 NaN
# 524                           the fucking nitro stout                 NaN
# 527                           beer art project gótica                 NaN
# 596                          albert the great batch 2                 NaN
# 600                   guineu vitis malvasia manresana                 NaN
# 628             no nation brewing co ttt derma series                 NaN
# 631                          lo vilot verema garnatxa                 NaN
# 640                            wylie brewery headspin                 NaN
# 657   premium distribución de cervezas hopsession ipa                 NaN
# 658                   indiano cerveza artesana cañera                 NaN
# 659                                       smach silda                 NaN
# 660                                 cerveza veer veer                 NaN
# 662                                   caleya románica                 NaN
# 664                                      milana lager                 NaN
# 665                       catalan brewery beach bunny                 NaN
# ...                                               ...                 ...
# 7192                                          marisma                 NaN
# 7223                                        can vador                 NaN
# 7236                                alentorn pale ale                 NaN
# 7247                                     lola vintage                 NaN
# 7284                                    gala de flors                 NaN
# 7288                                món beer barcinum                 NaN
# 7306         bayyana edición especial 1er aniversario                 NaN
# 7307                                         bdn agoa                 NaN
# 7344                                              bdn                 NaN
# 7345                                   balearis major                 NaN
# 7347                                         bdn 1897                 NaN
# 7403                                        wavi alba                 NaN
# 7404                                       wavi negra                 NaN
# 7405                                     wavi tostada                 NaN
# 7406                                    wavi colorada                 NaN
# 7407                                       wavi rubia                 NaN
# 7441                                  damm free limón                 NaN
# 7521             el oso y el cuervo vendetta de malta                 NaN
# 7602                                 tramuntana amber                 NaN
# 7603                                  tramuntana suau                 NaN
# 7604                                 tramuntana negra                 NaN
# 7605                                 tramuntana rotja                 NaN
# 7606                                 tramuntana rossa                 NaN
# 7689                        la birra del mandril pils                 NaN
# 7734                             estraperlo brown ale  Cervesa Estraperlo
# 7735                                   estraperlo ale  Cervesa Estraperlo
# 7740                                calamanda torrada                 NaN
# 7741                               calamanda nocturna                 NaN
# 7742                                  calamanda negra                 NaN
# 7798                         estrella de navidad 2012                 NaN
#
#                              Style   ABV   IBU Description_full  \
# 29             Foreign Extra Stout   6.0   NaN              NaN
# 33                    American IPA   5.5   NaN              NaN
# 64               American Pale Ale   5.5   NaN              NaN
# 103              American Pale Ale   0.0   NaN              NaN
# 105                          Stout  12.0  40.0              NaN
# 159                   American IPA   6.0  60.0              NaN
# 207                 India Pale Ale   6.8  50.0              NaN
# 252       Schwarzbier (Black Beer)   4.3   NaN              NaN
# 321                New England IPA   4.7   NaN              NaN
# 333             Belgian Blonde Ale   6.0   NaN              NaN
# 381                    Sweet Stout   4.8  24.0              NaN
# 382                     Blonde Ale   4.9   NaN              NaN
# 383                       Sour Ale   4.7   NaN              NaN
# 386                   Fruit Lambic   5.6   NaN              NaN
# 471                      IPA Otros   6.4   NaN              NaN
# 523                      Cream Ale   5.6   NaN              NaN
# 524                 Imperial Stout  10.0   NaN              NaN
# 527                     Doppelbock   7.5   NaN              NaN
# 596                 Imperial Stout  12.0  55.0              NaN
# 600                     Fruit Beer   5.5   NaN              NaN
# 628                   American IPA   6.5  75.0              NaN
# 631                     Fruit Beer   5.5  25.0              NaN
# 640                New England IPA   6.7   NaN              NaN
# 657                 India Pale Ale   4.5  50.0              NaN
# 658                   Imperial IPA   7.7   NaN              NaN
# 659                  English Brown   5.5  28.0              NaN
# 660                        Pilsner   4.5   NaN              NaN
# 662                   American IPA   6.0   NaN              NaN
# 664                     Pale Lager   5.0   NaN              NaN
# 665                      IPA Otros   6.4   NaN              NaN
# ...                            ...   ...   ...              ...
# 7192                    Blonde Ale   4.6   NaN              NaN
# 7223                           Ale   5.5   NaN              NaN
# 7236                      Pale Ale   5.8   NaN              NaN
# 7247  Spice, Herb o Vegetable Beer   5.5   NaN              NaN
# 7284                           Ale   5.0   NaN              NaN
# 7288            Belgian Blonde Ale   5.7   NaN              NaN
# 7306                       Pilsner   4.5   NaN              NaN
# 7307                   No Definido   NaN   NaN              NaN
# 7344             American Pale Ale   6.1  75.0              NaN
# 7345                       Pilsner   5.0   NaN              NaN
# 7347                         Stout   6.2  35.0              NaN
# 7403                       Witbier   3.5  19.0              NaN
# 7404                  Brown Porter   5.0  32.0              NaN
# 7405                      Pale Ale   4.9  33.0              NaN
# 7406                 Irish Red Ale   5.0  34.0              NaN
# 7407              Weizen-Weissbier   4.5  31.0              NaN
# 7441               Shandy / Radler   0.0   NaN              NaN
# 7521                     Amber Ale   6.8  45.0              NaN
# 7602                     Amber Ale   5.0   NaN              NaN
# 7603                   Light Lager   3.9   NaN              NaN
# 7604                         Stout   6.0   NaN              NaN
# 7605                       Red Ale   5.0   NaN              NaN
# 7606                         Lager   4.8   NaN              NaN
# 7689                       Pilsner   5.6   NaN              NaN
# 7734            American Brown Ale   5.0   NaN              NaN
# 7735                    Golden Ale   5.0   NaN              NaN
# 7740                           Ale   NaN   NaN              NaN
# 7741                   No Definido   NaN   NaN              NaN
# 7742                           Ale   NaN   NaN              NaN
# 7798                         Lager   5.5   NaN              NaN
#
#      Description_full_clean
# 29                      NaN
# 33                      NaN
# 64                      NaN
# 103                     NaN
# 105                     NaN
# 159                     NaN
# 207                     NaN
# 252                     NaN
# 321                     NaN
# 333                     NaN
# 381                     NaN
# 382                     NaN
# 383                     NaN
# 386                     NaN
# 471                     NaN
# 523                     NaN
# 524                     NaN
# 527                     NaN
# 596                     NaN
# 600                     NaN
# 628                     NaN
# 631                     NaN
# 640                     NaN
# 657                     NaN
# 658                     NaN
# 659                     NaN
# 660                     NaN
# 662                     NaN
# 664                     NaN
# 665                     NaN
# ...                     ...
# 7192                    NaN
# 7223                    NaN
# 7236                    NaN
# 7247                    NaN
# 7284                    NaN
# 7288                    NaN
# 7306                    NaN
# 7307                    NaN
# 7344                    NaN
# 7345                    NaN
# 7347                    NaN
# 7403                    NaN
# 7404                    NaN
# 7405                    NaN
# 7406                    NaN
# 7407                    NaN
# 7441                    NaN
# 7521                    NaN
# 7602                    NaN
# 7603                    NaN
# 7604                    NaN
# 7605                    NaN
# 7606                    NaN
# 7689                    NaN
# 7734                    NaN
# 7735                    NaN
# 7740                    NaN
# 7741                    NaN
# 7742                    NaN
# 7798                    NaN
#
# [413 rows x 7 columns]

# %% [markdown]
# # Stopwords

# %%
df['Description_full_clean'] = df['Description_full_clean'].fillna('')

# %%
stopwords_list = stopwords.words('english') + stopwords.words('spanish')
df['Description_2'] = df['Description_full_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords_list)]))

# %% [markdown]
# # Unique words

# %%
df["Description_2"] = df["Description_2"].apply(lambda x: pd.unique(x.split(' ')))
df["Description_2"] = df["Description_2"].apply(lambda x: ' '.join(x))

# %%
df[['Name_clean', 'Description_full', 'Description_2']].sample(5)
# Out:
#                                   Name_clean  \
# 4149                           sra maltworth
# 4262             dobleerre imperial rufis ii
# 1477  península hazy vibes columbus amarillo
# 32                    edge brewing frequency
# 3184                             toupiña une
#
#                                                                                                                                                                                                                                                                                                               Description_full  \
# 4149                                                                                                                                                                                                                                                                                                                       NaN
# 4262                                                                                                                                                                                                                                                                                                                       NaN
# 1477  Hazy Vibes: Columbus y Amarillo\nDDH IPA de 40 IBUS, forma parte de nuestra nueva Hazy Vibes Series. Esta IPA con Double Dry-Hop de Columbus y Amarillo es seca y refrescante a pesar de sus 7 grados. El aroma recuerda al de la naranja y el pomelo con ... Ver más leve especiado aportado por el Columbus. Ver menos
# 32                                                                                                                                                                                                                                                                                                 Frequency\nHoppy Golden Ale
# 3184                                                                           Toupiña UNE\r\nProfundo vermello-cobrizo, moderadamente forte, maltosa, complexa, con ricos sabores de malte, ésteres a froitas escuras ou secas, e lixeiro alcol mesturados xuntos nunha presentación que aunque maltosa remata bastante seca.
#
#                                                                                                                                                                                                           Description_2
# 4149
# 4262
# 1477              ddh ipa 40 ibus, forma parte nueva hazy vibes series. double dry-hop columbus amarillo seca refrescante pesar 7 grados. aroma recuerda naranja pomelo ... ver leve especiado aportado columbus. menos
# 32                                                                                                                                                                                                     hoppy golden ale
# 3184  profundo vermello-cobrizo, moderadamente forte, maltosa, complexa, ricos sabores malte, ésteres froitas escuras ou secas, lixeiro alcol mesturados xuntos nunha presentación aunque maltosa remata bastante seca.

# %% [markdown]
# # Remove words

# %%
list_words_to_drop = ['beer', 'beers', 'cerveza', 'cervezas', 'la', 'una', 'elaborada', 'el', 'hop', 'hops', 'lupulo', 'lupulos']

# %%
df["Description_2"] = df["Description_2"].apply(lambda x: [word for word in x.split() if word not in list_words_to_drop])
df["Description_2"] = df["Description_2"].apply(lambda x: ' '.join(x))
df['Description_2'] = df['Description_2'].map(lambda x: re.sub(r'\W+', ' ', x)).str.lower()

# %%
df[['Description_full', 'Description_2']].sample(5)
# Out:
#                                                                                                                                                                                                                                                                                         Description_full  \
# 1132                                                                                                                                                                                                                                                                            Sisyphus\nGalaxy DDH IPA
# 1962                                                                                                                                                                                                                                                                                                 NaN
# 2742                                                                        Estrella Galicia Pimientos Padrón\r\nUnas pican e outras non.\r\nCerveza de pimientos de Padrón,  con lúpulo gallego, tiene 6,5 grados de alcohol y un picante que difiere en función de la apreciación de cada consumidor.
# 7657  Bayura Mexu de Trasgu India Pale Ale doble carga de lúpulo\r\nAromática con marcados matices cítricos y tropicales, aparecen tambien toques de resina de pino y de bosque. En boca es amarga, con recuerdos resinosos, cítricos y ligeramente minerales. ... Ver más seco y bien amargo. Ver menos
# 1449                                                                                      Gayaspera\nFolixa asturiana en una botella. Las maltas tostadas y los lúpulos nobles alemanes dan carácter a esta lager de tonos rojizos, cargada de aromas y sabores a caramelo y un ligero final torrefacto.
#
#                                                                                                                                                                           Description_2
# 1132                                                                                                                                                                     galaxy ddh ipa
# 1962
# 2742                                                                            pimientos padrón lúpulo gallego 6 5 grados alcohol picante difiere función apreciación cada consumidor
# 7657  bayura aromática marcados matices cítricos tropicales aparecen tambien toques resina pino bosque boca amarga recuerdos resinosos ligeramente minerales ver seco bien amargo menos
# 1449                         folixa asturiana botella maltas tostadas lúpulos nobles alemanes dan carácter lager tonos rojizos cargada aromas sabores caramelo ligero final torrefacto

# %% [markdown]
# # English dictionary

# %%
df['Description_3'] = df['Description_2'].apply(lambda x: pd.unique(x.split()))

# %%
results = set()
df['Description_3'].apply(results.update)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
#         ...
# 7849    None
# 7850    None
# 7851    None
# 7852    None
# 7853    None
# 7854    None
# 7855    None
# 7856    None
# 7857    None
# 7858    None
# 7859    None
# 7860    None
# 7861    None
# 7862    None
# 7863    None
# 7864    None
# 7865    None
# 7866    None
# 7867    None
# 7868    None
# 7869    None
# 7870    None
# 7871    None
# 7872    None
# 7873    None
# 7874    None
# 7875    None
# 7876    None
# 7877    None
# 7878    None
# Name: Description_3, Length: 7879, dtype: object

# %%
results = list(results)

# %%
len(results)  # number of unique words
# Out:
# 25790

# %%
d = enchant.Dict("en_US")
# d.check("Hello")

# %%
results_english = []

for element in results:
    if d.check(element):
        results_english.append(element)

# %%
len(results_english)  # number of unique english words
# Out:
# 3611

# %% [markdown]
# # Translator

# %%
# dict_trans = {}

# %%
# translator = Translator()

# %%
# for element in results_english:
#     if element not in dict_trans.keys():
#         dict_trans[element] = translator.translate(element, src="en", dest="es").text

# %%
# with open('dict_english.json', 'w') as fp:
#     json.dump(dict_trans, fp)

# %%
with open('dict_english.json') as json_file:
    dict_trans = json.load(json_file)

# %%
len(dict_trans)
# Out:
# 3755

# %%
english_words = ['pale', 'ale', 'ales', 'brew', 'shandy', 'shandys', 'hazy', 'dry', 'warrior',
                 'galaxy', 'mosaic', 'england', 'new', 'porter', 'toque', 'hops', 'cashmere', 'melon', 'secret', 'centennial']

# %%
def func_lambda(x):
    text = []    
    for element in x:
        if element in dict_trans.keys() and element not in english_words:
            element = dict_trans[element]
        text.append(element)
    return ' '.join(text)

# %%
df['Description_spanish'] = df['Description_3'].apply(func_lambda).str.lower()
df["Description_spanish"] = df["Description_spanish"].apply(lambda x: pd.unique(x.split(' ')))
df["Description_spanish"] = df["Description_spanish"].apply(lambda x: ' '.join(x))

# %%
# df["Description_spanish"] = df["Description_spanish"].apply(lambda x: [int(s) for s in x.split() if not s.isdigit()])
# df["Description_spanish"] = df["Description_spanish"].apply(lambda x: ' '.join(x))
# re.findall(r'\d+', 'hello 42 I\'m a 32 string 30')

# %%
df[['Name_clean', 'Description_full', 'Description_spanish']].sample(5)
# Out:
#                              Name_clean  \
# 5729           the angry brewery beleak
# 4659                 toutatis la blonde
# 1311  barcelona beer company santa rita
# 93            basqueland oloroso beltza
# 5333            la quince horny pilsner
#
#                                                                                                                                                                                                                                                                                                                                                                                                                              Description_full  \
# 5729                                                                                                                                                                                                                                                                                                                                                                                                The angry Brewery Beleak\n\r\nExtra Stout
# 4659  Toutatis La Blonde\r\nCerveza rubia de estilo Belga que a diferencia de las rubias pale ale y lager típicas, tiene un dulzor y cuerpo más marcado, combinado con frutados procedentes de la levadura.\r\nLa sensación que aporta la malta de estilo Belga ... Ver más los frutados procedentes de la levadura de abadías hacen de ésta una cerveza compleja sin necesidad de ingredientes aromatizantes ni lúpulos marcados.  Ver menos
# 1311                                                                                                                                                                                                                                                                                                                                                                                                          Santa Rita\nPremium Craft Lager
# 93                                                                                                                                                                                                                                                                                                                                                                                     Oloroso Beltza\nImperial Stout aged in Oloroso barrels
# 5333                                                                                                                                                                                                                                                                                                                                                                           La Quince Horny Pilsner\r\nUna Hoppy Pils para beber sin parar
#
#                                                                                                                                                                                                                        Description_spanish
# 5729                                                                                                                                                                                                                   extra cerveza negra
# 4659  rubia estilo belga diferencia rubias pale ale lager típicas dulzor cuerpo marcado c sensación aporta malta ver frutados procedentes levadura abadías hacen ésta compleja necesidad ingredientes aromatizantes lúpulos marcados menos
# 1311                                                                                                                                                                                                                      prima arte lager
# 93                                                                                                                                                                                      imperial cerveza negra envejecido oloroso barriles
# 5333                                                                                                                                                                                                                hoppy pils beber parar

# %% [markdown]
# # Extract hops

# %%
hops_list = ['mosaic', 'citra', 'amarillo', 'simcoe', 'cascade', 'columbus',
             'chinook', 'cashmere', 't90', 'ekuanot', 'mandarina bavaria', 'galaxy', 'idaho 7',
             'hüll melon', 'enigma', 'vic secret', 'willamette', 'warrior', 'centennial', 'nelson sauvin', 'galena', 'ahtanum', 'mandarina']

# %%
# TO DO
# Incluir lúpulos de dos palabras, ahora mismo se están sacando los de una única palabra

# %%
df['hops'] = df['Description_spanish'].apply(lambda x: ([word for word in x.split() if word in (hops_list)]))

# %%
df.sample(2)
# Out:
#                       Name_clean              Brewery_full              Style  \
# 3442  filabres american pale ale  Cervezas de los Filabres  American Pale Ale
# 5952      hopland a n a ai pi ei        Hopland Cerveceros        English IPA
#
#       ABV   IBU  \
# 3442  5.0   NaN
# 5952  4.9  62.0
#
#                                                                                                                                                                                                                                    Description_full  \
# 3442  Filabres American Pale Ale\r\nElaborada en Velefique con dos tipos de maltas base y dos especiales además de los lúpulos en flor. Aroma y sabor dominado por el carácter de los cereales. Cerveza de fermentación alta y ligeramente especiad
# 5952    A.N.A. Ai Pi Ei es la evolución de nuestra Blonde Ale A.N.A. A Naughty Ale. Pertenece a la categoria de las English IPA. Su amargor es moderado y la gran variedad de lúpulos empleados le dan un gran y complejo aroma. Su color es ambar.
#
#                                                                                                                                                                                                                            Description_full_clean  \
# 3442                              elaborada en velefique con dos tipos de maltas base y dos especiales además de los lúpulos en flor. aroma y sabor dominado por el carácter de los cereales. cerveza de fermentación alta y ligeramente especiad
# 5952  a.n.a. ai pi ei es la evolución de nuestra blonde ale a.n.a. a naughty ale. pertenece a la categoria de las english ipa. su amargor es moderado y la gran variedad de lúpulos empleados le dan un gran y complejo aroma. su color es ambar.
#
#                                                                                                                                                          Description_2  \
# 3442                      velefique dos tipos maltas base especiales además lúpulos flor aroma sabor dominado carácter cereales fermentación alta ligeramente especiad
# 5952  a n a ai pi ei evolución blonde ale naughty ale pertenece categoria english ipa amargor moderado gran variedad lúpulos empleados dan complejo aroma color ambar
#
#                                                                                                                                                                            Description_3  \
# 3442                     [velefique, dos, tipos, maltas, base, especiales, además, lúpulos, flor, aroma, sabor, dominado, carácter, cereales, fermentación, alta, ligeramente, especiad]
# 5952  [a, n, ai, pi, ei, evolución, blonde, ale, naughty, pertenece, categoria, english, ipa, amargor, moderado, gran, variedad, lúpulos, empleados, dan, complejo, aroma, color, ambar]
#
#                                                                                                                                                 Description_spanish  \
# 3442                   velefique dos tipos maltas base especiales además lúpulos flor aroma sabor dominado carácter cereales fermentación alta ligeramente especiad
# 5952  a norte ai pi ei evolución rubia ale travieso pertenece categoria english ipa amargor moderado gran variedad lúpulos empleados dan complejo aroma color ambar
#
#      hops
# 3442   []
# 5952   []

# %% [markdown]
# # Extract fruits

# %%
fruit_list = ['naranja', 'pomelo', 'mango', 'frambuesas']

# %%
df['fruits'] = df['Description_spanish'].apply(lambda x: ([word for word in x.split() if word in (fruit_list)]))

# %%
df.sample(2)
# Out:
#                   Name_clean          Brewery_full              Style  ABV  \
# 4901  tu aperitivo compartir  Tu AperitivoBirra 08           Pale Ale  5.4
# 5635                 crápula       Cerveza Crápula  American Pale Ale  5.1
#
#        IBU  \
# 4901   NaN
# 5635  38.0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Description_full  \
# 4901  Hemos creado junto con los Cerveceros Artesanales de Birra08, la Cerveza Artesanal Compartir, la Cerveza del Aperitivo. Una Cerveza del estilo Pale Ale con 5,4% de alcohol. Una Cerveza diseñada para disfrutar de los complementos de un buen Aperitivo. ... Ver más Cerveza de tuaperitivo.\r\nEn nariz presenta toques cítricos de mandarina u orangina. Con ligero aroma floral y con toque de vainilla ligera.\r\nEn boca es equilibrada, con un punto de aguja que acentua su carácter fresco. Encontramo...
# 5635                                                                                                                                                                                                                                                                                                     Crápula\n\r\nCrápula es un individuo al que le gusta el desenfreno, no tiene la vida ordenada, es inmoral y esta en contra de las buenas costumbres.\n\r\nAmerican Pale Ale con 3 maltas y 4 lúpulos americanos.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Description_full_clean  \
# 4901  hemos creado junto con los cerveceros artesanales de birra08, la cerveza artesanal compartir, la cerveza del aperitivo. una cerveza del estilo pale ale con 5,4% de alcohol. una cerveza diseñada para disfrutar de los complementos de un bu en nariz presenta toques cítricos de mandarina u orangina. con li en boca es equilibrada, con un punto de aguja que acentua su carácter fresco. encontramos las maltas integradas y un final cítrico y seco. este final seco, la hace ideal para el ap para tomar ...
# 5635                                                                                                                                                                                                                                                                                                                                                                        crápula es un individuo al que le gusta el desenfreno, no tiene la vida ordenada, es   american pale ale con 3 maltas y 4 lúpulos americanos.
#
#                                                                                                                                                                                                                                                                                                                                                                             Description_2  \
# 4901  creado junto cerveceros artesanales birra08 artesanal compartir aperitivo estilo pale ale 5 4 alcohol diseñada disfrutar complementos bu nariz presenta toques cítricos mandarina u orangina li boca equilibrada punto aguja acentua carácter fresco encontramos maltas integradas final cítrico seco seco hace ideal ap tomar conservas patatas fritas gourmet aceitunas ver menos
# 5635                                                                                                                                                                                                                                                                                    crápula individuo gusta desenfreno vida ordenada american pale ale 3 maltas 4 lúpulos americanos
#
#                                                                                                                                                                                                                                                                                                                                                                                                                           Description_3  \
# 4901  [creado, junto, cerveceros, artesanales, birra08, artesanal, compartir, aperitivo, estilo, pale, ale, 5, 4, alcohol, diseñada, disfrutar, complementos, bu, nariz, presenta, toques, cítricos, mandarina, u, orangina, li, boca, equilibrada, punto, aguja, acentua, carácter, fresco, encontramos, maltas, integradas, final, cítrico, seco, hace, ideal, ap, tomar, conservas, patatas, fritas, gourmet, aceitunas, ver, menos]
# 5635                                                                                                                                                                                                                                                                                                                    [crápula, individuo, gusta, desenfreno, vida, ordenada, american, pale, ale, 3, maltas, 4, lúpulos, americanos]
#
#                                                                                                                                                                                                                                                                                                                                                                     Description_spanish  \
# 4901  creado junto cerveceros artesanales birra08 artesanal compartir aperitivo estilo pale ale 5 4 alcohol diseñada disfrutar complementos bu nariz presenta toques cítricos mandarina u orangina li boca equilibrada punto aguja acentua carácter fresco encontramos maltas integradas final cítrico seco hace ideal ap tomar conservas patatas fritas gastrónomo aceitunas ver menos
# 5635                                                                                                                                                                                                                                                                                   crápula individuo gusta desenfreno vida ordenada american pale ale 3 maltas 4 lúpulos americanos
#
#              hops fruits
# 4901  [mandarina]     []
# 5635           []     []

# %% [markdown]
# # NLP

# %% [markdown]
# ## Stemming

# %%
# Keep root of words

stemmer = SnowballStemmer("spanish")
df['Spanish_stemmed'] = df["Description_spanish"].map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))
# df["stemmed_clean"] = df['stemmed'].map(lambda x: re.sub(r'\W+', ' ', x))

# %%
df[['Name_clean', 'Description_spanish', 'Spanish_stemmed']].sample(5)
# Out:
#                         Name_clean  \
# 7357  archi pilsen bohemia premium
# 4873              mangurria yihipa
# 5550                   gara tomasa
# 3919           fort barcelona pils
# 7181            la baturra tostada
#
#                                                                                                                                                                                                                 Description_spanish  \
# 7357                                                 natural inconfundible color dorado sabor auténtico duradero fruto mejor tradición cervecera exclusivamente agua madrid 100 pura malta cebada selección lúpulos nobles levadura
# 4873                                                                                                                                                                                                             artesana ecológica
# 5550                                                                                                                                                                                                  gara tomasa negra dunkel bock
# 3919                                                                                                                                                                        fuerte bcn pils rene cada trago autenticidad bien hecha
# 7181  artesanal intensa delicada saborear forma pausada relajada maltas alta calidad mezcla lúpulos levaduras tipo ale color tostado sabor caramelo aromas recuerdan cereales tostados notas ver secos ideal acompañar carnes menos
#
#                                                                                                                                                                     Spanish_stemmed
# 7357                                   natural inconfund color dor sabor autent durader frut mejor tradicion cervecer exclus agu madr 100 pur malt ceb seleccion lupul nobl levadur
# 4873                                                                                                                                                                 artesan ecolog
# 5550                                                                                                                                                     gar tomas negr dunkel bock
# 3919                                                                                                                                   fuert bcn pils ren cad trag autent bien hech
# 7181  artesanal intens delic sabor form paus relaj malt alta calid mezcl lupul levadur tip ale color tost sabor caramel arom recuerd cereal tost not ver sec ideal acompañ carn men

# %% [markdown]
# ## PorterStemmer

# %%
# stemmer = PorterStemmer()
# df['Description_3'] = df["Description_3"].map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))

# %% [markdown]
# ## CountVectorizer

# %%
cvec = CountVectorizer(
#     stop_words=["english", "spanish"], 
    stop_words=["spanish"],     
    min_df=0.01, 
    max_df=0.50, 
    ngram_range=(1,3) # change to consider bigrams
#     ngram_range=(1) # unigrams
)
cvec
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=0.5, max_features=None, min_df=0.01,
#                 ngram_range=(1, 3), preprocessor=None, stop_words=['spanish'],
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
# cvec.fit(df['Description_3'])
# cvec.fit(df['Description_spanish'])
cvec.fit(df['Spanish_stemmed'])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=0.5, max_features=None, min_df=0.01,
#                 ngram_range=(1, 3), preprocessor=None, stop_words=['spanish'],
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
cvec.get_feature_names()
# Out:
# ['10',
#  '100',
#  'abund',
#  'abv',
#  'acab',
#  'acid',
#  'acidez',
#  'acompañ',
#  'ademas',
#  'adicion',
#  'afabl',
#  'afrut',
#  'agrad',
#  'agri',
#  'agu',
#  'ahum',
#  'alc',
#  'alcohol',
#  'ale',
#  'ale color',
#  'aleman',
#  'alta',
#  'alta ferment',
#  'alto',
#  'amarg',
#  'amargor',
#  'amargur',
#  'amarill',
#  'amb',
#  'ambar',
#  'americ',
#  'americ pal',
#  'americ pal ale',
#  'american',
#  'amig',
#  'anaranj',
#  'aparient',
#  'aperit',
#  'aport',
#  'apreci',
#  'aquest',
#  'arom',
#  'arom citric',
#  'arom frut',
#  'arom intens',
#  'arom lupul',
#  'arom malt',
#  'arom sabor',
#  'aromat',
#  'artesan',
#  'artesanal',
#  'asad',
#  'asi',
#  'aspect',
#  'aunqu',
#  'autent',
#  'aven',
#  'azuc',
#  'azul',
#  'añad',
#  'año',
#  'años',
#  'baj',
#  'balanc',
#  'barric',
#  'barril',
#  'bas',
#  'beb',
#  'belg',
#  'belgi',
#  'bien',
#  'blanc',
#  'blat',
#  'boc',
#  'botell',
#  'brillant',
#  'bronc',
#  'buen',
#  'burbuj',
#  'busc',
#  'caca',
#  'cad',
#  'caf',
#  'calid',
#  'cantid',
#  'caract',
#  'caracterist',
#  'caracteriz',
#  'caramel',
#  'carameliz',
#  'carbon',
#  'carbonat',
#  'carbonat medi',
#  'carbonat medi de',
#  'carg',
#  'carn',
#  'cas',
#  'casc',
#  'casi',
#  'ceb',
#  'cebador',
#  'centen',
#  'cereal',
#  'cervec',
#  'cervecer',
#  'cerves',
#  'cervez',
#  'cervez negr',
#  'chinook',
#  'chocolat',
#  'ciert',
#  'cilantr',
#  'citr',
#  'citric',
#  'clar',
#  'clasic',
#  'co',
#  'cobriz',
#  'colabor',
#  'color',
#  'color amarill',
#  'color ambar',
#  'color cobriz',
#  'color dor',
#  'color negr',
#  'columbus',
#  'com',
#  'combin',
#  'complej',
#  'comun',
#  'confier',
#  'conoc',
#  'consegu',
#  'conserv',
#  'consistent',
#  'consum',
#  'conten',
#  'contien',
#  'conviert',
#  'cop',
#  'coron',
#  'cos',
#  'cost',
#  'cre',
#  'crem',
#  'cremos',
#  'cristal',
#  'cualqui',
#  'cuatr',
#  'cuerp',
#  'cuerp liger',
#  'cuerp medi',
#  'da',
#  'dan',
#  'ddh',
#  'de',
#  'de comun',
#  'deb',
#  'degust',
#  'dej',
#  'delic',
#  'dens',
#  'despues',
#  'destac',
#  'dia',
#  'diferent',
#  'diseñ',
#  'disfrut',
#  'dobl',
#  'dobl ipa',
#  'dor',
#  'dos',
#  'dry',
#  'dry salt',
#  'dulc',
#  'dulzor',
#  'ecolog',
#  'edicion',
#  'edicion limit',
#  'elabor',
#  'eleg',
#  'els',
#  'emple',
#  'en',
#  'encontr',
#  'england',
#  'ensal',
#  'entrad',
#  'entusiasm',
#  'envejec',
#  'equilibr',
#  'equilibri',
#  'es',
#  'escum',
#  'especi',
#  'especial',
#  'espum',
#  'espum blanc',
#  'espum cremos',
#  'espum dens',
#  'estil',
#  'etiquet',
#  'extra',
#  'fabric',
#  'facil',
#  'facil beb',
#  'ferment',
#  'filtr',
#  'fin',
#  'final',
#  'final sec',
#  'flor',
#  'floral',
#  'fond',
#  'form',
#  'fresc',
#  'fri',
#  'frut',
#  'frut sec',
#  'frut tropical',
#  'frutal',
#  'fuert',
#  'gallet',
#  'gener',
#  'general',
#  'graci',
#  'grad',
#  'graduacion',
#  'graduacion alcohol',
#  'gran',
#  'grand',
#  'gust',
#  'hac',
#  'hech',
#  'herbal',
#  'herbari',
#  'hierb',
#  'homenaj',
#  'ibu',
#  'ibus',
#  'ideal',
#  'imperial',
#  'imperial cervez',
#  'imperial cervez negr',
#  'indi',
#  'indi pal',
#  'indi pal ale',
#  'ingles',
#  'ingredient',
#  'inspir',
#  'integr',
#  'intens',
#  'intens arom',
#  'inviern',
#  'invit',
#  'ipa',
#  'junt',
#  'just',
#  'la',
#  'lactos',
#  'lag',
#  'larg',
#  'lev',
#  'levadur',
#  'liger',
#  'limit',
#  'limon',
#  'limpi',
#  'lleg',
#  'llen',
#  'llev',
#  'llupol',
#  'llupols',
#  'lupul',
#  'lupul american',
#  'lupul levadur',
#  'mader',
#  'madur',
#  'maestr',
#  'malt',
#  'malt ceb',
#  'malt lupul',
#  'malt pal',
#  'malt tost',
#  'maltos',
#  'mandarin',
#  'maner',
#  'mang',
#  'mar',
#  'marc',
#  'marid',
#  'maridaj',
#  'marisc',
#  'marron',
#  'mas',
#  'matic',
#  'medi',
#  'medi de',
#  'medi de comun',
#  'mejor',
#  'melocoton',
#  'men',
#  'mes',
#  'mezcl',
#  'miel',
#  'mism',
#  'moder',
#  'moment',
#  'mosaic',
#  'much',
#  'mud',
#  'mund',
#  'munich',
#  'nac',
#  'naranj',
#  'nariz',
#  'natural',
#  'negr',
#  'new',
#  'new england',
#  'nobl',
#  'nombr',
#  'nort',
#  'not',
#  'not citric',
#  'nuev',
#  'ofrec',
#  'olor',
#  'orig',
#  'original',
#  'oscur',
#  'pag',
#  'pal',
#  'pal ale',
#  'palad',
#  'pan',
#  'part',
#  'pas',
#  'past',
#  'pasteuriz',
#  'pens',
#  'pequeñ',
#  'perfect',
#  'perfil',
#  'persistent',
#  'pes',
#  'pesc',
#  'picant',
#  'piel',
#  'piel naranj',
#  'pils',
#  'pilsn',
#  'pimient',
#  'pin',
#  'plat',
#  'platan',
#  'poc',
#  'pod',
#  'pomel',
#  'por',
#  'port',
#  'postr',
#  'potent',
#  'predomin',
#  'presenci',
#  'present',
#  'prim',
#  'primer',
#  'proces',
#  'produc',
#  'product',
#  'profund',
#  'propi',
#  'proporcion',
#  'protagon',
#  'pued',
#  'punt',
#  'pur',
#  'que',
#  'quer',
#  'ques',
#  'realiz',
#  'recet',
#  'recomend',
#  'recuerd',
#  'redond',
#  'reflej',
#  'refresc',
#  'refrescant',
#  'regaliz',
#  'resin',
#  'result',
#  'retrogust',
#  'ric',
#  'robl',
#  'robust',
#  'roj',
#  'rojiz',
#  'rubi',
#  'sabor',
#  'sabor arom',
#  'sabor intens',
#  'sabor malt',
#  'sabros',
#  'saison',
#  'sal',
#  'salt',
#  'sec',
#  'sedos',
#  'segund',
#  'seleccion',
#  'sensacion',
#  'sensacion boc',
#  'sent',
#  'ser',
#  'seri',
#  'serv',
#  'sesion',
#  'sesion ipa',
#  'seu',
#  'si',
#  'sid',
#  'siempr',
#  'simco',
#  'sol',
#  'sorprend',
#  'suav',
#  'sutil',
#  'temperatur',
#  'termin',
#  'textur',
#  'tiemp',
#  'tierr',
#  'tip',
#  'tip malt',
#  'tipic',
#  'tod',
#  'tom',
#  'ton',
#  'toqu',
#  'toqu citric',
#  'torrefact',
#  'tost',
#  'tradicion',
#  'tradicional',
#  'trag',
#  'trat',
#  'tres',
#  'trig',
#  'tropical',
#  'turbi',
#  'turbidez',
#  'una',
#  'unic',
#  'utiliz',
#  'va',
#  'vainill',
#  'varied',
#  'variedad',
#  'vas',
#  'ver',
#  'ver men',
#  'veran',
#  'verd',
#  'version',
#  'vez',
#  'vin',
#  'viv',
#  'vol']

# %%
list(islice(cvec.vocabulary_.items(), 20))
# Out:
# [('estil', 200),
#  ('tradicional', 444),
#  ('elabor', 179),
#  ('malt', 279),
#  ('pilsn', 351),
#  ('trig', 448),
#  ('aven', 56),
#  ('caracteriz', 87),
#  ('adicion', 9),
#  ('casc', 97),
#  ('naranj', 314),
#  ('amarg', 24),
#  ('cilantr', 111),
#  ('agri', 13),
#  ('mejor', 299),
#  ('ipa', 255),
#  ('frut', 217),
#  ('sec', 407),
#  ('aromat', 48),
#  ('amargor', 25)]

# %%
# cvec_counts = cvec.transform(df['Description_3'])
# cvec_counts = cvec.transform(df['Description_spanish'])
cvec_counts = cvec.transform(df['Spanish_stemmed'])

print('sparse matrix shape:', cvec_counts.shape)
print('nonzero count:', cvec_counts.nnz)
print('sparsity: %.2f%%' % (100.0 * cvec_counts.nnz / (cvec_counts.shape[0] * cvec_counts.shape[1])))
# Out:
# sparse matrix shape: (7879, 469)
# nonzero count: 124299
# sparsity: 3.36%

# %%
# top 20 terms
occ = np.asarray(cvec_counts.sum(axis=0)).ravel().tolist()
counts_df = pd.DataFrame({'term': cvec.get_feature_names(), 'occurrences': occ})

# %%
counts_df.sort_values(by='occurrences', ascending=False).head(10)
# Out:
#         term  occurrences
# 301      men         3721
# 460      ver         3720
# 279     malt         2613
# 41      arom         2545
# 273    lupul         2489
# 399    sabor         2235
# 119    color         1944
# 264    liger         1496
# 18       ale         1496
# 25   amargor         1250

# %% [markdown]
# ## TfidfTransformer

# %%
# use tfidf transformer to calc weights
transformer = TfidfTransformer()
transformed_weights = transformer.fit_transform(cvec_counts)
transformed_weights
# Out:
# <7879x469 sparse matrix of type '<class 'numpy.float64'>'
# 	with 124299 stored elements in Compressed Sparse Row format>

# %%
# beer_name = 'Malandar Silk'
# beer_name = 'Arriaca Triple IPA'
# beer_name = 'Alegría del Barrio'
beer_name = 'la grúa bamboo'

# Compute cosine similarity with a beer of choice, that is represented in the dataset
idx = df.index.get_indexer_for((df[df['Name_clean']==beer_name].index))[0]

# %%
df[df.Name_clean.str.contains('alegría')]['Name_clean']
# Out:
# 987         alegría pink revolution ipa 2019
# 1889    grx brewing alegría comandante mango
# 3030                alegría del mediterráneo
# 4322      alegría boris brew ipanosuarus rex
# 4665     alegría pirate brew juanito polarez
# 4787                        alegría de vivir
# 5045                     la jerezana alegría
# 6986                       alegría del valle
# 6987                         alegría del sur
# 6988                      alegría del barrio
# 6989                          alegría mcmiau
# Name: Name_clean, dtype: object

# %% [markdown]
# ## Cosine Similarity

# %%
df_recommendation = df[['Name_clean', 'Brewery_full', 'IBU', 'Style', 'Description_full', 'Description_spanish', 'hops']]

# %%
sims = cosine_similarity(transformed_weights[idx, :], transformed_weights)

# Add similarities values to the beer description dataframe, then sort by similarities descending
df_recommendation['sims'] = sims.T
df_recommendation.sort_values(by='sims', ascending=False).head(20)
# Out:
# /home/cx02358/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                                            Name_clean  \
# 405                                    la grúa bamboo
# 3531                            mad brewing camarillo
# 3448            la quince 15 hours session ipa mosaic
# 1241                               biribil eguzkilore
# 1322                            the flying inn lilith
# 1504                                  baias singapore
# 1670                         basqueland brut reynolds
# 6131                       tro ales single hop mosaic
# 1919  laugar brussels beer project the lauter revenge
# 1091             la quince señor lúpulo tsunami neipa
# 350                         naparbier lonesome mosaic
# 674                               jakobsland we exist
# 1289                     basqueland double everything
# 1541                              wylie brewery ukiyo
# 1123                                     caleya lloba
# 528                        attik brewing ace vendetta
# 2421                     la quince jurassic milkshake
# 2273                                    caleya ayalga
# 1779                     garage beer co virtue signal
# 6488                       fort local beer mosaic apa
#
#                                               Brewery_full   IBU  \
# 405                                       Cervezas La Grúa   NaN
# 3531                                           Mad Brewing   NaN
# 3448                                     La Quince Brewery  55.0
# 1241                                       Biribil Brewing   NaN
# 1322                                        The Flying Inn  70.0
# 1504                                  Baias Garagardotegia   NaN
# 1670                            Basqueland Brewing Project   NaN
# 6131                                              Tro Ales  50.0
# 1919                   Laugar BreweryBrussels Beer Project   NaN
# 1091                         La Quince BrewerySeñor Lúpulo   NaN
# 350                                              Naparbier   NaN
# 674                                     Jakobsland Brewers  25.0
# 1289  Basqueland Brewing ProjectGipsy Hill Brewing Company  40.0
# 1541                                         Wylie Brewery  46.0
# 1123                                        Cerveza Caleya   NaN
# 528                                          Attik Brewing   NaN
# 2421                                     La Quince Brewery   NaN
# 2273                                        Cerveza Caleya   NaN
# 1779                                        Garage Beer Co  55.0
# 6488                                          Cerveza Fort   NaN
#
#                   Style  \
# 405     New England IPA
# 3531     India Pale Ale
# 3448     India Pale Ale
# 1241    New England IPA
# 1322     India Pale Ale
# 1504   India Pale Lager
# 1670     India Pale Ale
# 6131  American Pale Ale
# 1919       American IPA
# 1091    New England IPA
# 350        American IPA
# 674     New England IPA
# 1289       Imperial IPA
# 1541       American IPA
# 1123          IPA Otros
# 528     New England IPA
# 2421       American IPA
# 2273     India Pale Ale
# 1779     India Pale Ale
# 6488  American Pale Ale
#
#                                                                                                                                                                                                                                              Description_full  \
# 405                                                                                                                                                                                        Bamboo\nDDH NEIPA\nCon lúpulos Idaho 7, Mosaic, Cashmere y avena\n
# 3531                                                                                                                                                                                                 Mad Brewing Camarillo\r\nIPA con avena y lúpulo Mosaic\n
# 3448                                                                                                                                                                                  La Quince 15 Hours Session IPA Mosaic\r\nMonovarietal de lúpulo Mosaic.
# 1241                                                                                                                               Eguzkilore\nHazy IPA\nAvena, turbiedad, levadura Vermont y lúpulos Mosaic y Amarillo a paladas para un aroma espectacular.
# 1322                                                                                                                                                                                 Lilith\nIPA Pale malt, oat malt, wheat malt, cara malt. Mosaic, Ekuanot.
# 1504                                                                                                                                                                                                                                Singapore\nIPL 6%\nMosaic
# 1670                                                                                                                                                Brut Reynolds\nDDH Brut IPA\nA beer dedicated to the late, great Burt Reynolds.\nCryo Simcoe\nCryo Mosaic
# 6131                                                                                                                                                                                                                             Tro Ales Single Hop Mosaic\n
# 1919                                                                                                                                                                                                                    The Lauter Revenge\r\nNEIPA con avena
# 1091                                                                                                  Tsunami NEIPA\nCollab with Señor Lúpulo Gijón\nMalts: golden promise, wheat and oats. Hops: Ekuanot, Mosaic, Summit, Polaris and Cascade. Vermont yeast
# 350                                                                                                                                                                                                                          Lonesome Mosaic\nHazy IPA Mosaic
# 674                                                                                                                                                                                                                    We Exist\nVic Secret, Bru1, Mosaic IPA
# 1289                                                                                                                                     Double Everything DIPA\nDouble India Pale Ale\nLúpulos: Ahtanum, Cryo Simcoe, Enigma, Simcoe T90, Vic Secret, Mosaic
# 1541                                                                                                          Ukiyo\nIPA\nHazy IPA with flaked oats, oat milk and oat malt. Centennial, Nelson Sauvin, Mosaic and Galena as the bittering hops. Feel the flow
# 1123                                                                                                                                                                     Lloba\nOat IPA\nNueva cerveza de la serie Quantica, Lloba Oat Ipa\nIPA de avena de 7
# 528   Ace Vendetta\nDDH NEIPA\nNeIPA elaborada con lúpulos Ekuanot, Mosaic y Citra. Una cerveza hiper afrutada que explota en boca, con un toque de avena que le aporta sedosidad para que sea de trago fácil. Muy fresco y para los paladares más exigentes.
# 2421             La Quince Jurassic Milkshake\r\nMilkshake NEIPA\r\nTribute Ale Brewed With Bloody Passion\r\nCon lactosa, trigo, avena, maris otter, levadura de nueva Inglaterra y los siguientes lúpulos: Willamette, mandarina, simcoe, mosaic y warrior.
# 2273                                                                                                                                                                                                    Caleya Ayalga\r\nIndia Pale Ale\r\nCon avena y trigo.
# 1779                                                                                                                                                                        Virtue Signal\r\nIndia Pale Ale\r\nIPA con los lúpulos palisade, simcoe y mosaic.
# 6488                                                                                                                                                                                                                               Fort Local Beer Mosaic APA
#
#                                                                                                                      Description_spanish  \
# 405                                                                                                lúpulos idaho 7 mosaic cashmere avena
# 3531                                                                                                             ipa avena lúpulo mosaic
# 3448                                                                                                          monovarietal lúpulo mosaic
# 1241                                                 avena turbiedad levadura vermont lúpulos mosaic amarillo paladas aroma espectacular
# 1322                                                                                      ipa pale malta avena trigo cara mosaic ekuanot
# 1504                                                                                                                              mosaic
# 1670                                                                                                                         cryo mosaic
# 6131                                                                                                             tro ales soltero mosaic
# 1919                                                                                                                         neipa avena
# 1091                                       maltas dorado promesa trigo avena hops ekuanot mosaic cumbre polaris cascada vermont levadura
# 350                                                                                                                      hazy ipa mosaic
# 674                                                                                                           vic secret bru1 mosaic ipa
# 1289                                                                            lúpulos ahtanum cryo simcoe enigma t90 vic secret mosaic
# 1541                           hazy ipa en copos avena leche malta centennial nelson sauvin mosaic galena bittering hops sensación fluir
# 1123                                                                                                                         ipa avena 7
# 528   neipa lúpulos ekuanot mosaic citra hiper afrutada explota boca toque avena aporta sedosidad trago fácil fresco paladares exigentes
# 2421            lactosa trigo avena maris nutria levadura nueva inglaterra siguientes lúpulos willamette mandarina simcoe mosaic warrior
# 2273                                                                                                                         avena trigo
# 1779                                                                                                ipa lúpulos empalizada simcoe mosaic
# 6488                                                                                                             fuerte local mosaic apa
#
#                                                   hops      sims
# 405                                 [mosaic, cashmere]  1.000000
# 3531                                          [mosaic]  0.912488
# 3448                                          [mosaic]  0.753122
# 1241                                [mosaic, amarillo]  0.716840
# 1322                                 [mosaic, ekuanot]  0.691430
# 1504                                          [mosaic]  0.678311
# 1670                                          [mosaic]  0.678311
# 6131                                          [mosaic]  0.678311
# 1919                                                []  0.657880
# 1091                                 [ekuanot, mosaic]  0.597808
# 350                                           [mosaic]  0.565875
# 674                                           [mosaic]  0.565875
# 1289            [ahtanum, simcoe, enigma, t90, mosaic]  0.556269
# 1541                      [centennial, mosaic, galena]  0.547444
# 1123                                                []  0.543642
# 528                           [ekuanot, mosaic, citra]  0.538758
# 2421  [willamette, mandarina, simcoe, mosaic, warrior]  0.520351
# 2273                                                []  0.517438
# 1779                                  [simcoe, mosaic]  0.509217
# 6488                                          [mosaic]  0.505144
